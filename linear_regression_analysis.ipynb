# %%
import ipywidgets as widgets
from IPython.display import display

import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.api as sm

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Data

# %% [markdown]
# ## Age group dataset

# %%
ag_df = pd.read_csv("./final_dataset/age_group_incidence.csv").dropna()

# %% [markdown]
# ### Regions

# %%
regions = ag_df.region.unique()

regions
# Out:
# array(['Вінницька', 'Волинська', 'Дніпропетровська', 'Донецька',
#        'Житомирська', 'Закарпатська', 'Запорізька', 'Івано-Франківська',
#        'Київська', 'Кіровоградська', 'Луганська', 'Львівська',
#        'Миколаївська', 'Одеська', 'Полтавська', 'Рівненська', 'Сумська',
#        'Тернопільська', 'Харківська', 'Херсонська', 'Хмельницька',
#        'Черкаська', 'Чернівецька', 'Чернігівська'], dtype=object)

# %% [markdown]
# ### Age groups

# %%
age_groups = ag_df.age_group.unique()

age_groups
# Out:
# array(['до 1 р.', '1-4 р.', '5-9 р.', '10-14р', '15-19р', 'в т.ч. 15-17р',
#        '20-24р', '25-29р', '30-34р', '35-39р', '40-44р', '45-49р',
#        '50-54р', '55-59р', '60-64р', '65-69р', '70-74р', '75-79р',
#        '80-84р', '85 та старші'], dtype=object)

# %% [markdown]
# ### Region-age groups combinations:

# %%
models_data_groups = list(itertools.product(age_groups, regions))

models_data_groups
# Out:
# [('до 1 р.', 'Вінницька'),
#  ('до 1 р.', 'Волинська'),
#  ('до 1 р.', 'Дніпропетровська'),
#  ('до 1 р.', 'Донецька'),
#  ('до 1 р.', 'Житомирська'),
#  ('до 1 р.', 'Закарпатська'),
#  ('до 1 р.', 'Запорізька'),
#  ('до 1 р.', 'Івано-Франківська'),
#  ('до 1 р.', 'Київська'),
#  ('до 1 р.', 'Кіровоградська'),
#  ('до 1 р.', 'Луганська'),
#  ('до 1 р.', 'Львівська'),
#  ('до 1 р.', 'Миколаївська'),
#  ('до 1 р.', 'Одеська'),
#  ('до 1 р.', 'Полтавська'),
#  ('до 1 р.', 'Рівненська'),
#  ('до 1 р.', 'Сумська'),
#  ('до 1 р.', 'Тернопільська'),
#  ('до 1 р.', 'Харківська'),
#  ('до 1 р.', 'Херсонська'),
#  ('до 1 р.', 'Хмельницька'),
#  ('до 1 р.', 'Черкаська'),
#  ('до 1 р.', 'Чернівецька'),
#  ('до 1 р.', 'Чернігівська'),
#  ('1-4 р.', 'Вінницька'),
#  ('1-4 р.', 'Волинська'),
#  ('1-4 р.', 'Дніпропетровська'),
#  ('1-4 р.', 'Донецька'),
#  ('1-4 р.', 'Житомирська'),
#  ('1-4 р.', 'Закарпатська'),
#  ('1-4 р.', 'Запорізька'),
#  ('1-4 р.', 'Івано-Франківська'),
#  ('1-4 р.', 'Київська'),
#  ('1-4 р.', 'Кіровоградська'),
#  ('1-4 р.', 'Луганська'),
#  ('1-4 р.', 'Львівська'),
#  ('1-4 р.', 'Миколаївська'),
#  ('1-4 р.', 'Одеська'),
#  ('1-4 р.', 'Полтавська'),
#  ('1-4 р.', 'Рівненська'),
#  ('1-4 р.', 'Сумська'),
#  ('1-4 р.', 'Тернопільська'),
#  ('1-4 р.', 'Харківська'),
#  ('1-4 р.', 'Херсонська'),
#  ('1-4 р.', 'Хмельницька'),
#  ('1-4 р.', 'Черкаська'),
#  ('1-4 р.', 'Чернівецька'),
#  ('1-4 р.', 'Чернігівська'),
#  ('5-9 р.', 'Вінницька'),
#  ('5-9 р.', 'Волинська'),
#  ('5-9 р.', 'Дніпропетровська'),
#  ('5-9 р.', 'Донецька'),
#  ('5-9 р.', 'Житомирська'),
#  ('5-9 р.', 'Закарпатська'),
#  ('5-9 р.', 'Запорізька'),
#  ('5-9 р.', 'Івано-Франківська'),
#  ('5-9 р.', 'Київська'),
#  ('5-9 р.', 'Кіровоградська'),
#  ('5-9 р.', 'Луганська'),
#  ('5-9 р.', 'Львівська'),
#  ('5-9 р.', 'Миколаївська'),
#  ('5-9 р.', 'Одеська'),
#  ('5-9 р.', 'Полтавська'),
#  ('5-9 р.', 'Рівненська'),
#  ('5-9 р.', 'Сумська'),
#  ('5-9 р.', 'Тернопільська'),
#  ('5-9 р.', 'Харківська'),
#  ('5-9 р.', 'Херсонська'),
#  ('5-9 р.', 'Хмельницька'),
#  ('5-9 р.', 'Черкаська'),
#  ('5-9 р.', 'Чернівецька'),
#  ('5-9 р.', 'Чернігівська'),
#  ('10-14р', 'Вінницька'),
#  ('10-14р', 'Волинська'),
#  ('10-14р', 'Дніпропетровська'),
#  ('10-14р', 'Донецька'),
#  ('10-14р', 'Житомирська'),
#  ('10-14р', 'Закарпатська'),
#  ('10-14р', 'Запорізька'),
#  ('10-14р', 'Івано-Франківська'),
#  ('10-14р', 'Київська'),
#  ('10-14р', 'Кіровоградська'),
#  ('10-14р', 'Луганська'),
#  ('10-14р', 'Львівська'),
#  ('10-14р', 'Миколаївська'),
#  ('10-14р', 'Одеська'),
#  ('10-14р', 'Полтавська'),
#  ('10-14р', 'Рівненська'),
#  ('10-14р', 'Сумська'),
#  ('10-14р', 'Тернопільська'),
#  ('10-14р', 'Харківська'),
#  ('10-14р', 'Херсонська'),
#  ('10-14р', 'Хмельницька'),
#  ('10-14р', 'Черкаська'),
#  ('10-14р', 'Чернівецька'),
#  ('10-14р', 'Чернігівська'),
#  ('15-19р', 'Вінницька'),
#  ('15-19р', 'Волинська'),
#  ('15-19р', 'Дніпропетровська'),
#  ('15-19р', 'Донецька'),
#  ('15-19р', 'Житомирська'),
#  ('15-19р', 'Закарпатська'),
#  ('15-19р', 'Запорізька'),
#  ('15-19р', 'Івано-Франківська'),
#  ('15-19р', 'Київська'),
#  ('15-19р', 'Кіровоградська'),
#  ('15-19р', 'Луганська'),
#  ('15-19р', 'Львівська'),
#  ('15-19р', 'Миколаївська'),
#  ('15-19р', 'Одеська'),
#  ('15-19р', 'Полтавська'),
#  ('15-19р', 'Рівненська'),
#  ('15-19р', 'Сумська'),
#  ('15-19р', 'Тернопільська'),
#  ('15-19р', 'Харківська'),
#  ('15-19р', 'Херсонська'),
#  ('15-19р', 'Хмельницька'),
#  ('15-19р', 'Черкаська'),
#  ('15-19р', 'Чернівецька'),
#  ('15-19р', 'Чернігівська'),
#  ('в т.ч. 15-17р', 'Вінницька'),
#  ('в т.ч. 15-17р', 'Волинська'),
#  ('в т.ч. 15-17р', 'Дніпропетровська'),
#  ('в т.ч. 15-17р', 'Донецька'),
#  ('в т.ч. 15-17р', 'Житомирська'),
#  ('в т.ч. 15-17р', 'Закарпатська'),
#  ('в т.ч. 15-17р', 'Запорізька'),
#  ('в т.ч. 15-17р', 'Івано-Франківська'),
#  ('в т.ч. 15-17р', 'Київська'),
#  ('в т.ч. 15-17р', 'Кіровоградська'),
#  ('в т.ч. 15-17р', 'Луганська'),
#  ('в т.ч. 15-17р', 'Львівська'),
#  ('в т.ч. 15-17р', 'Миколаївська'),
#  ('в т.ч. 15-17р', 'Одеська'),
#  ('в т.ч. 15-17р', 'Полтавська'),
#  ('в т.ч. 15-17р', 'Рівненська'),
#  ('в т.ч. 15-17р', 'Сумська'),
#  ('в т.ч. 15-17р', 'Тернопільська'),
#  ('в т.ч. 15-17р', 'Харківська'),
#  ('в т.ч. 15-17р', 'Херсонська'),
#  ('в т.ч. 15-17р', 'Хмельницька'),
#  ('в т.ч. 15-17р', 'Черкаська'),
#  ('в т.ч. 15-17р', 'Чернівецька'),
#  ('в т.ч. 15-17р', 'Чернігівська'),
#  ('20-24р', 'Вінницька'),
#  ('20-24р', 'Волинська'),
#  ('20-24р', 'Дніпропетровська'),
#  ('20-24р', 'Донецька'),
#  ('20-24р', 'Житомирська'),
#  ('20-24р', 'Закарпатська'),
#  ('20-24р', 'Запорізька'),
#  ('20-24р', 'Івано-Франківська'),
#  ('20-24р', 'Київська'),
#  ('20-24р', 'Кіровоградська'),
#  ('20-24р', 'Луганська'),
#  ('20-24р', 'Львівська'),
#  ('20-24р', 'Миколаївська'),
#  ('20-24р', 'Одеська'),
#  ('20-24р', 'Полтавська'),
#  ('20-24р', 'Рівненська'),
#  ('20-24р', 'Сумська'),
#  ('20-24р', 'Тернопільська'),
#  ('20-24р', 'Харківська'),
#  ('20-24р', 'Херсонська'),
#  ('20-24р', 'Хмельницька'),
#  ('20-24р', 'Черкаська'),
#  ('20-24р', 'Чернівецька'),
#  ('20-24р', 'Чернігівська'),
#  ('25-29р', 'Вінницька'),
#  ('25-29р', 'Волинська'),
#  ('25-29р', 'Дніпропетровська'),
#  ('25-29р', 'Донецька'),
#  ('25-29р', 'Житомирська'),
#  ('25-29р', 'Закарпатська'),
#  ('25-29р', 'Запорізька'),
#  ('25-29р', 'Івано-Франківська'),
#  ('25-29р', 'Київська'),
#  ('25-29р', 'Кіровоградська'),
#  ('25-29р', 'Луганська'),
#  ('25-29р', 'Львівська'),
#  ('25-29р', 'Миколаївська'),
#  ('25-29р', 'Одеська'),
#  ('25-29р', 'Полтавська'),
#  ('25-29р', 'Рівненська'),
#  ('25-29р', 'Сумська'),
#  ('25-29р', 'Тернопільська'),
#  ('25-29р', 'Харківська'),
#  ('25-29р', 'Херсонська'),
#  ('25-29р', 'Хмельницька'),
#  ('25-29р', 'Черкаська'),
#  ('25-29р', 'Чернівецька'),
#  ('25-29р', 'Чернігівська'),
#  ('30-34р', 'Вінницька'),
#  ('30-34р', 'Волинська'),
#  ('30-34р', 'Дніпропетровська'),
#  ('30-34р', 'Донецька'),
#  ('30-34р', 'Житомирська'),
#  ('30-34р', 'Закарпатська'),
#  ('30-34р', 'Запорізька'),
#  ('30-34р', 'Івано-Франківська'),
#  ('30-34р', 'Київська'),
#  ('30-34р', 'Кіровоградська'),
#  ('30-34р', 'Луганська'),
#  ('30-34р', 'Львівська'),
#  ('30-34р', 'Миколаївська'),
#  ('30-34р', 'Одеська'),
#  ('30-34р', 'Полтавська'),
#  ('30-34р', 'Рівненська'),
#  ('30-34р', 'Сумська'),
#  ('30-34р', 'Тернопільська'),
#  ('30-34р', 'Харківська'),
#  ('30-34р', 'Херсонська'),
#  ('30-34р', 'Хмельницька'),
#  ('30-34р', 'Черкаська'),
#  ('30-34р', 'Чернівецька'),
#  ('30-34р', 'Чернігівська'),
#  ('35-39р', 'Вінницька'),
#  ('35-39р', 'Волинська'),
#  ('35-39р', 'Дніпропетровська'),
#  ('35-39р', 'Донецька'),
#  ('35-39р', 'Житомирська'),
#  ('35-39р', 'Закарпатська'),
#  ('35-39р', 'Запорізька'),
#  ('35-39р', 'Івано-Франківська'),
#  ('35-39р', 'Київська'),
#  ('35-39р', 'Кіровоградська'),
#  ('35-39р', 'Луганська'),
#  ('35-39р', 'Львівська'),
#  ('35-39р', 'Миколаївська'),
#  ('35-39р', 'Одеська'),
#  ('35-39р', 'Полтавська'),
#  ('35-39р', 'Рівненська'),
#  ('35-39р', 'Сумська'),
#  ('35-39р', 'Тернопільська'),
#  ('35-39р', 'Харківська'),
#  ('35-39р', 'Херсонська'),
#  ('35-39р', 'Хмельницька'),
#  ('35-39р', 'Черкаська'),
#  ('35-39р', 'Чернівецька'),
#  ('35-39р', 'Чернігівська'),
#  ('40-44р', 'Вінницька'),
#  ('40-44р', 'Волинська'),
#  ('40-44р', 'Дніпропетровська'),
#  ('40-44р', 'Донецька'),
#  ('40-44р', 'Житомирська'),
#  ('40-44р', 'Закарпатська'),
#  ('40-44р', 'Запорізька'),
#  ('40-44р', 'Івано-Франківська'),
#  ('40-44р', 'Київська'),
#  ('40-44р', 'Кіровоградська'),
#  ('40-44р', 'Луганська'),
#  ('40-44р', 'Львівська'),
#  ('40-44р', 'Миколаївська'),
#  ('40-44р', 'Одеська'),
#  ('40-44р', 'Полтавська'),
#  ('40-44р', 'Рівненська'),
#  ('40-44р', 'Сумська'),
#  ('40-44р', 'Тернопільська'),
#  ('40-44р', 'Харківська'),
#  ('40-44р', 'Херсонська'),
#  ('40-44р', 'Хмельницька'),
#  ('40-44р', 'Черкаська'),
#  ('40-44р', 'Чернівецька'),
#  ('40-44р', 'Чернігівська'),
#  ('45-49р', 'Вінницька'),
#  ('45-49р', 'Волинська'),
#  ('45-49р', 'Дніпропетровська'),
#  ('45-49р', 'Донецька'),
#  ('45-49р', 'Житомирська'),
#  ('45-49р', 'Закарпатська'),
#  ('45-49р', 'Запорізька'),
#  ('45-49р', 'Івано-Франківська'),
#  ('45-49р', 'Київська'),
#  ('45-49р', 'Кіровоградська'),
#  ('45-49р', 'Луганська'),
#  ('45-49р', 'Львівська'),
#  ('45-49р', 'Миколаївська'),
#  ('45-49р', 'Одеська'),
#  ('45-49р', 'Полтавська'),
#  ('45-49р', 'Рівненська'),
#  ('45-49р', 'Сумська'),
#  ('45-49р', 'Тернопільська'),
#  ('45-49р', 'Харківська'),
#  ('45-49р', 'Херсонська'),
#  ('45-49р', 'Хмельницька'),
#  ('45-49р', 'Черкаська'),
#  ('45-49р', 'Чернівецька'),
#  ('45-49р', 'Чернігівська'),
#  ('50-54р', 'Вінницька'),
#  ('50-54р', 'Волинська'),
#  ('50-54р', 'Дніпропетровська'),
#  ('50-54р', 'Донецька'),
#  ('50-54р', 'Житомирська'),
#  ('50-54р', 'Закарпатська'),
#  ('50-54р', 'Запорізька'),
#  ('50-54р', 'Івано-Франківська'),
#  ('50-54р', 'Київська'),
#  ('50-54р', 'Кіровоградська'),
#  ('50-54р', 'Луганська'),
#  ('50-54р', 'Львівська'),
#  ('50-54р', 'Миколаївська'),
#  ('50-54р', 'Одеська'),
#  ('50-54р', 'Полтавська'),
#  ('50-54р', 'Рівненська'),
#  ('50-54р', 'Сумська'),
#  ('50-54р', 'Тернопільська'),
#  ('50-54р', 'Харківська'),
#  ('50-54р', 'Херсонська'),
#  ('50-54р', 'Хмельницька'),
#  ('50-54р', 'Черкаська'),
#  ('50-54р', 'Чернівецька'),
#  ('50-54р', 'Чернігівська'),
#  ('55-59р', 'Вінницька'),
#  ('55-59р', 'Волинська'),
#  ('55-59р', 'Дніпропетровська'),
#  ('55-59р', 'Донецька'),
#  ('55-59р', 'Житомирська'),
#  ('55-59р', 'Закарпатська'),
#  ('55-59р', 'Запорізька'),
#  ('55-59р', 'Івано-Франківська'),
#  ('55-59р', 'Київська'),
#  ('55-59р', 'Кіровоградська'),
#  ('55-59р', 'Луганська'),
#  ('55-59р', 'Львівська'),
#  ('55-59р', 'Миколаївська'),
#  ('55-59р', 'Одеська'),
#  ('55-59р', 'Полтавська'),
#  ('55-59р', 'Рівненська'),
#  ('55-59р', 'Сумська'),
#  ('55-59р', 'Тернопільська'),
#  ('55-59р', 'Харківська'),
#  ('55-59р', 'Херсонська'),
#  ('55-59р', 'Хмельницька'),
#  ('55-59р', 'Черкаська'),
#  ('55-59р', 'Чернівецька'),
#  ('55-59р', 'Чернігівська'),
#  ('60-64р', 'Вінницька'),
#  ('60-64р', 'Волинська'),
#  ('60-64р', 'Дніпропетровська'),
#  ('60-64р', 'Донецька'),
#  ('60-64р', 'Житомирська'),
#  ('60-64р', 'Закарпатська'),
#  ('60-64р', 'Запорізька'),
#  ('60-64р', 'Івано-Франківська'),
#  ('60-64р', 'Київська'),
#  ('60-64р', 'Кіровоградська'),
#  ('60-64р', 'Луганська'),
#  ('60-64р', 'Львівська'),
#  ('60-64р', 'Миколаївська'),
#  ('60-64р', 'Одеська'),
#  ('60-64р', 'Полтавська'),
#  ('60-64р', 'Рівненська'),
#  ('60-64р', 'Сумська'),
#  ('60-64р', 'Тернопільська'),
#  ('60-64р', 'Харківська'),
#  ('60-64р', 'Херсонська'),
#  ('60-64р', 'Хмельницька'),
#  ('60-64р', 'Черкаська'),
#  ('60-64р', 'Чернівецька'),
#  ('60-64р', 'Чернігівська'),
#  ('65-69р', 'Вінницька'),
#  ('65-69р', 'Волинська'),
#  ('65-69р', 'Дніпропетровська'),
#  ('65-69р', 'Донецька'),
#  ('65-69р', 'Житомирська'),
#  ('65-69р', 'Закарпатська'),
#  ('65-69р', 'Запорізька'),
#  ('65-69р', 'Івано-Франківська'),
#  ('65-69р', 'Київська'),
#  ('65-69р', 'Кіровоградська'),
#  ('65-69р', 'Луганська'),
#  ('65-69р', 'Львівська'),
#  ('65-69р', 'Миколаївська'),
#  ('65-69р', 'Одеська'),
#  ('65-69р', 'Полтавська'),
#  ('65-69р', 'Рівненська'),
#  ('65-69р', 'Сумська'),
#  ('65-69р', 'Тернопільська'),
#  ('65-69р', 'Харківська'),
#  ('65-69р', 'Херсонська'),
#  ('65-69р', 'Хмельницька'),
#  ('65-69р', 'Черкаська'),
#  ('65-69р', 'Чернівецька'),
#  ('65-69р', 'Чернігівська'),
#  ('70-74р', 'Вінницька'),
#  ('70-74р', 'Волинська'),
#  ('70-74р', 'Дніпропетровська'),
#  ('70-74р', 'Донецька'),
#  ('70-74р', 'Житомирська'),
#  ('70-74р', 'Закарпатська'),
#  ('70-74р', 'Запорізька'),
#  ('70-74р', 'Івано-Франківська'),
#  ('70-74р', 'Київська'),
#  ('70-74р', 'Кіровоградська'),
#  ('70-74р', 'Луганська'),
#  ('70-74р', 'Львівська'),
#  ('70-74р', 'Миколаївська'),
#  ('70-74р', 'Одеська'),
#  ('70-74р', 'Полтавська'),
#  ('70-74р', 'Рівненська'),
#  ('70-74р', 'Сумська'),
#  ('70-74р', 'Тернопільська'),
#  ('70-74р', 'Харківська'),
#  ('70-74р', 'Херсонська'),
#  ('70-74р', 'Хмельницька'),
#  ('70-74р', 'Черкаська'),
#  ('70-74р', 'Чернівецька'),
#  ('70-74р', 'Чернігівська'),
#  ('75-79р', 'Вінницька'),
#  ('75-79р', 'Волинська'),
#  ('75-79р', 'Дніпропетровська'),
#  ('75-79р', 'Донецька'),
#  ('75-79р', 'Житомирська'),
#  ('75-79р', 'Закарпатська'),
#  ('75-79р', 'Запорізька'),
#  ('75-79р', 'Івано-Франківська'),
#  ('75-79р', 'Київська'),
#  ('75-79р', 'Кіровоградська'),
#  ('75-79р', 'Луганська'),
#  ('75-79р', 'Львівська'),
#  ('75-79р', 'Миколаївська'),
#  ('75-79р', 'Одеська'),
#  ('75-79р', 'Полтавська'),
#  ('75-79р', 'Рівненська'),
#  ('75-79р', 'Сумська'),
#  ('75-79р', 'Тернопільська'),
#  ('75-79р', 'Харківська'),
#  ('75-79р', 'Херсонська'),
#  ('75-79р', 'Хмельницька'),
#  ('75-79р', 'Черкаська'),
#  ('75-79р', 'Чернівецька'),
#  ('75-79р', 'Чернігівська'),
#  ('80-84р', 'Вінницька'),
#  ('80-84р', 'Волинська'),
#  ('80-84р', 'Дніпропетровська'),
#  ('80-84р', 'Донецька'),
#  ('80-84р', 'Житомирська'),
#  ('80-84р', 'Закарпатська'),
#  ('80-84р', 'Запорізька'),
#  ('80-84р', 'Івано-Франківська'),
#  ('80-84р', 'Київська'),
#  ('80-84р', 'Кіровоградська'),
#  ('80-84р', 'Луганська'),
#  ('80-84р', 'Львівська'),
#  ('80-84р', 'Миколаївська'),
#  ('80-84р', 'Одеська'),
#  ('80-84р', 'Полтавська'),
#  ('80-84р', 'Рівненська'),
#  ('80-84р', 'Сумська'),
#  ('80-84р', 'Тернопільська'),
#  ('80-84р', 'Харківська'),
#  ('80-84р', 'Херсонська'),
#  ('80-84р', 'Хмельницька'),
#  ('80-84р', 'Черкаська'),
#  ('80-84р', 'Чернівецька'),
#  ('80-84р', 'Чернігівська'),
#  ('85 та старші', 'Вінницька'),
#  ('85 та старші', 'Волинська'),
#  ('85 та старші', 'Дніпропетровська'),
#  ('85 та старші', 'Донецька'),
#  ('85 та старші', 'Житомирська'),
#  ('85 та старші', 'Закарпатська'),
#  ('85 та старші', 'Запорізька'),
#  ('85 та старші', 'Івано-Франківська'),
#  ('85 та старші', 'Київська'),
#  ('85 та старші', 'Кіровоградська'),
#  ('85 та старші', 'Луганська'),
#  ('85 та старші', 'Львівська'),
#  ('85 та старші', 'Миколаївська'),
#  ('85 та старші', 'Одеська'),
#  ('85 та старші', 'Полтавська'),
#  ('85 та старші', 'Рівненська'),
#  ('85 та старші', 'Сумська'),
#  ('85 та старші', 'Тернопільська'),
#  ('85 та старші', 'Харківська'),
#  ('85 та старші', 'Херсонська'),
#  ('85 та старші', 'Хмельницька'),
#  ('85 та старші', 'Черкаська'),
#  ('85 та старші', 'Чернівецька'),
#  ('85 та старші', 'Чернігівська')]

# %% [markdown]
# ### Cancer statistics categories

# %%
all_categories = list(ag_df.category.unique())

total_male_category = "Злоякiснi новоутворення-всього         C00-C97    ч"
total_female_category = "C00-C97    ж"

localization_categories = all_categories.copy()
localization_categories.remove(total_male_category)
localization_categories.remove(total_female_category)

male_localization_categories = [category for category in localization_categories if category.endswith('ч')]
female_localization_categories = [category for category in localization_categories if category.endswith('ж')]

# %% [markdown]
# ## Stage dataset

# %%
st_df = pd.read_csv("./final_dataset/stage_incidence_features.csv")

st_df["age_group"] = "all"
st_df['category'] = "all"

st_df = st_df.dropna()

st_df.head()
# Out:
#    year            region  mtumors  syncmtumors  insitu  ncervix  \
# 0  2010         Вінницька      356          112     113      103
# 1  2010         Волинська      177           50      81       77
# 2  2010  Дніпропетровська      767          212     174      150
# 3  2010          Донецька      906          234      57       24
# 4  2010       Житомирська      285           94      33       30
#
#    nhospotal_pht  nbeds_pht  ybeds_pht    nill_pht  ...    cpi  \
# 0         6.6036   753.7223   752.6318  22315.1106  ...  109.1
# 1         5.0161   738.2327   737.9433  22185.9521  ...  109.1
# 2         4.6193   885.5064   890.8410  24009.1361  ...  109.1
# 3         3.8731   719.4061   720.7270  20000.7836  ...  109.1
# 4         5.3661   670.4520   671.6107  21998.0729  ...  109.1
#
#    population_pht  tincidence_pht  mtumors_pht  syncmtumors_pht  insitu_pht  \
# 0        100000.0        338.4813    21.567810         6.785378    6.845962
# 1        100000.0        274.4377    17.073982         4.823159    7.813517
# 2        100000.0        366.8625    22.858124         6.318021    5.185546
# 3        100000.0        337.7855    20.283249         5.238720    1.276098
# 4        100000.0        307.7344    22.164344         7.310345    2.566398
#
#    insitu_pti  mtumors_pti  age_group  category
# 0   20.225524    63.719348        all       all
# 1   28.471002    62.214411        all       all
# 2   14.134850    62.307067        all       all
# 3    3.777837    60.047720        all       all
# 4    8.339651    72.024261        all       all
#
# [5 rows x 47 columns]

# %% [markdown]
# # Model selection

# %%
def select_best_model_for(df: pd.DataFrame, target: str, ommit: list[str]) -> tuple[sm.OLS, list[str]]:
    predictors = df.drop(columns=ommit + [target], errors="ignore")

    predictors = predictors.select_dtypes(include=["number"])
    
    X = predictors.copy()
    y = df[target]
    
    X = sm.add_constant(X)
    
    best_model = sm.OLS(y, X).fit()

    best_aic = np.inf

    to_drop = None

    while len(X.columns) > 0:
        aic_not_changed = True
            
        for col in X.columns:
            temp_X = X.drop(col, axis = 1)
            temp_model = sm.OLS(y, temp_X).fit()
            if temp_model.aic < best_aic:
                best_aic = temp_model.aic
                best_model = temp_model
                to_drop = col
                aic_not_changed = False

        if aic_not_changed:
            break

        X = X.drop(to_drop, axis = 1)
    
    return best_model

# %%
class Model:

    def __init__(self, name: str, ols: sm.OLS, identifier: tuple[str]):
        self.name = name
        self.ols = ols
        self.identifier = identifier

    def display_summary(self):
        original_summary = str(self.ols.summary())
        without_title = '\n'.join(original_summary.split('\n')[1:])
        new_summary = f"{self.name:^78}\n"
        new_summary += f"{"Category:":<{20}} {self.identifier[0]:>{57}}\n"
        new_summary += f"{"Region:":<{20}} {self.identifier[1]:>{57}}\n"
        new_summary += f"{"Age group:":<{20}} {self.identifier[2]:>{57}}\n"
        new_summary += without_title
        print(new_summary)

    def get_df(self, df: pd.DataFrame):
        category, region, age_group = self.identifier

        if category == '__all__':
            mask = (df.region == region) & (df.age_group == age_group)
        elif region == '__all__':
            mask = (df.category == category) & (df.age_group == age_group)
        elif age_group == '__all__':
            mask = (df.category == category) & (df.region == region)
        else:
            mask = (df.category == category) & (df.region == region) & (df.age_group == age_group)

        return df[mask]


def filter_models(models: dict[tuple, Model], categories: list[str] = None, regions: list[str] = None, age_groups: list[str] = None):
    filtered_models = []
    for model_identifier, model in models.items():
        category, region, age_group = model_identifier
        if categories and category not in categories:
            continue

        if regions and region not in regions:
            continue
        
        if age_groups and age_group not in age_groups:
            continue
            
        filtered_models.append(model)

    return filtered_models

# %% [markdown]
# ### Level-level models

# %%
import multiprocessing
import multiprocessing.queues

def worker(queue, models_identifiers, target, ommit, df):
    for category, region, age_group in models_identifiers:

        if category == '__all__':
            mask = (df.region == region) & (df.age_group == age_group)
        elif region == '__all__':
            mask = (df.category == category) & (df.age_group == age_group)
        elif age_group == '__all__':
            mask = (df.category == category) & (df.region == region)
        else:
            mask = (df.category == category) & (df.region == region) & (df.age_group == age_group)

        filtered_df = df[mask]
        best_model = select_best_model_for(filtered_df, target, ommit)
        model_identifier = (category, region, age_group)
        model = Model(f"Level-level Incidence model", 
                        ols=best_model,
                        identifier=model_identifier)
        queue.put(((category, region, age_group), model ))

def create_models_for(categories: list[str],
                      regions: list[str],
                      age_groups: list[str], 
                      df: pd.DataFrame,
                      target: str,
                      ommit: list,
                      njobs: int = 4) -> dict[tuple, Model]:
    models = {}

    progress = widgets.FloatProgress(value=0, min=0, max=len(regions)*len(age_groups), step=1)

    display(progress)

    model_identifiers = []

    for category in categories:
        for region in regions:
            for age_group in age_groups:
                model_identifiers.append((category, region, age_group))

    models_per_worker = len(model_identifiers) // njobs
    q = multiprocessing.Queue()
    processes = [ multiprocessing.Process(target=worker, args=(q, 
                                                               model_identifiers[i * models_per_worker: (i+1) * models_per_worker], 
                                                               target,
                                                               ommit,
                                                               df))
                                          for i in range(njobs) ]

    for p in processes:
        p.start()

    while any(p.is_alive() for p in processes) or not q.empty():
        try:
            identifier, model = q.get_nowait()
            models[identifier] = model
            progress.value += 1
        except multiprocessing.queues.Empty:
            pass


    return models

# %% [markdown]
# #### Male age region models

# %%
male_age_region_model = create_models_for(categories=[total_male_category],
                                         regions=regions,
                                         age_groups=age_groups,
                                         df=ag_df,
                                         target="incidence",
                                         ommit=["age_group", "year", "gdp", "region", "category"],
                                         njobs=12)
# Out:
# FloatProgress(value=0.0, max=480.0)

# %% [markdown]
# #### Female age region models

# %%
female_age_region_model = create_models_for(categories=[total_female_category],
                                            regions=regions,
                                            age_groups=age_groups,
                                            df=ag_df,
                                            target="incidence",
                                            ommit=["age_group", "year", "gdp", "region", "category"],
                                            njobs=12)
# Out:
# FloatProgress(value=0.0, max=480.0)

# %%
dnipro_models = filter_models(female_age_region_model, regions=['Дніпропетровська'])
dnipro_models[11].display_summary()
# Out:
#                          Level-level Incidence model
# Category:                                                         C00-C97    ж
# Region:                                                       Дніпропетровська
# Age group:                                                              45-49р
# ==============================================================================
# Dep. Variable:              incidence   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 26 Mar 2025   Prob (F-statistic):                nan
# Time:                        11:16:30   Log-Likelihood:                 282.86
# No. Observations:                  13   AIC:                            -539.7
# Df Residuals:                       0   BIC:                            -532.4
# Df Model:                          12
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# nhospotal                   -0.0350        inf         -0        nan         nan         nan
# nbeds                       -0.1541        inf         -0        nan         nan         nan
# ybeds                       -0.0205        inf         -0        nan         nan         nan
# nill                        -0.0004        inf         -0        nan         nan         nan
# nvillage_ill                -0.0027        inf         -0        nan         nan         nan
# bed_days                     0.0002        inf          0        nan         nan         nan
# dvisits                  -2.318e-05        inf         -0        nan         nan         nan
# ndoctors                     0.1574        inf          0        nan         nan         nan
# nnursing                     0.0604        inf          0        nan         nan         nan
# nx_ray                      -0.0042        inf         -0        nan         nan         nan
# nflurography                -0.0284        inf         -0        nan         nan         nan
# nradiology                   0.0079        inf          0        nan         nan         nan
# nradlab                     -0.0003        inf         -0        nan         nan         nan
# nсt                         -0.0172        inf         -0        nan         nan         nan
# ncardiogram                  0.1907        inf          0        nan         nan         nan
# ndiaglab                     0.0375        inf          0        nan         nan         nan
# nbacter                      0.0138        inf          0        nan         nan         nan
# nbiochem                    -0.0123        inf         -0        nan         nan         nan
# nimun                        0.0144        inf          0        nan         nan         nan
# nphysic                      0.0678        inf          0        nan         nan         nan
# nendoscop                   -0.0499        inf         -0        nan         nan         nan
# nultrasound                  0.1070        inf          0        nan         nan         nan
# ndialysis                   -0.0358        inf         -0        nan         nan         nan
# air_pollution               -0.0394        inf         -0        nan         nan         nan
# polluted_dumps               0.1846        inf          0        nan         nan         nan
# not_cleaned_dumps           -0.1290        inf         -0        nan         nan         nan
# dumps_not_cleaned_enough     0.6622        inf          0        nan         nan         nan
# num_clearing_plants          0.1766        inf          0        nan         nan         nan
# cpi                         -0.0041        inf         -0        nan         nan         nan
# population                   0.0005        inf          0        nan         nan         nan
# ==============================================================================
# Omnibus:                        2.126   Durbin-Watson:                   1.602
# Prob(Omnibus):                  0.345   Jarque-Bera (JB):                1.461
# Skew:                          -0.778   Prob(JB):                        0.482
# Kurtosis:                       2.474   Cond. No.                     3.24e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large, 3.24e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /home/zhukowych/.virtualenvs/ml/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:418: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=13 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /home/zhukowych/.virtualenvs/ml/lib/python3.12/site-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /home/zhukowych/.virtualenvs/ml/lib/python3.12/site-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /home/zhukowych/.virtualenvs/ml/lib/python3.12/site-packages/statsmodels/regression/linear_model.py:1717: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid

# %% [markdown]
# #### Multiple tumor detection model

# %%
st_df['t'] = st_df['year'] - 2008

# %%
ommit = ["age_group", "year", "region", "category",  'mtumors_pht', 'syncmtumors_pht',
         'insitu_pht', 'insitu_pti', 'mtumors_pti', 'ncervix', 'mtumors', 'syncmtumors', 'insitu', 
         'gdp', 'mtumors_pti', 'tincidence', 'tincidence_pht']

# %%
mtumors_model = select_best_model_for(st_df, "mtumors_pti", ommit=ommit)

# %%
print(mtumors_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            mtumors_pti   R-squared:                       0.657
# Model:                            OLS   Adj. R-squared:                  0.637
# Method:                 Least Squares   F-statistic:                     33.32
# Date:                Wed, 26 Mar 2025   Prob (F-statistic):           1.34e-58
# Time:                        11:16:31   Log-Likelihood:                -1123.6
# No. Observations:                 314   AIC:                             2283.
# Df Residuals:                     296   BIC:                             2351.
# Df Model:                          17
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# nhospotal_pht                2.1105      1.157      1.824      0.069      -0.167       4.388
# nill_pht                     0.0017      0.000      4.408      0.000       0.001       0.002
# nvillage_ill_pht            -0.0034      0.000     -9.576      0.000      -0.004      -0.003
# hvisits_pht                  0.0002   6.24e-05      3.010      0.003     6.5e-05       0.000
# ndoctors_pht                -0.1864      0.037     -4.972      0.000      -0.260      -0.113
# nnursing_pht                 0.0754      0.021      3.524      0.000       0.033       0.118
# nx_ray_pht                  -2.7206      1.661     -1.638      0.102      -5.989       0.548
# nflurography_pht             8.4543      1.794      4.712      0.000       4.923      11.986
# nradiology_pht              38.4266     11.930      3.221      0.001      14.948      61.905
# ncardiogram_pht              0.4572      0.295      1.552      0.122      -0.122       1.037
# nbacter_pht                 -4.1584      2.591     -1.605      0.110      -9.257       0.941
# nbiochem_pht               -12.4617      7.811     -1.595      0.112     -27.834       2.911
# nultrasound_pht             -4.7018      1.604     -2.931      0.004      -7.858      -1.545
# air_pollution               -0.0093      0.005     -1.802      0.073      -0.019       0.001
# not_cleaned_dumps           -0.0297      0.018     -1.681      0.094      -0.065       0.005
# dumps_not_cleaned_enough    -0.0233      0.015     -1.519      0.130      -0.053       0.007
# population_pht               0.0003   4.64e-05      6.839      0.000       0.000       0.000
# t                            3.6253      0.298     12.167      0.000       3.039       4.212
# ==============================================================================
# Omnibus:                        9.735   Durbin-Watson:                   1.812
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               16.393
# Skew:                           0.144   Prob(JB):                     0.000276
# Kurtosis:                       4.082   Cond. No.                     2.51e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.51e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### In situ model

# %%
insitu_model = select_best_model_for(st_df, "insitu_pti", ommit=ommit)

# %%
print(insitu_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             insitu_pti   R-squared:                       0.270
# Model:                            OLS   Adj. R-squared:                  0.231
# Method:                 Least Squares   F-statistic:                     6.861
# Date:                Wed, 26 Mar 2025   Prob (F-statistic):           2.35e-13
# Time:                        11:16:31   Log-Likelihood:                -1039.8
# No. Observations:                 314   AIC:                             2114.
# Df Residuals:                     297   BIC:                             2177.
# Df Model:                          16
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ybeds_pht              -0.0333      0.009     -3.587      0.000      -0.052      -0.015
# nill_pht                0.0007      0.000      2.357      0.019       0.000       0.001
# nvillage_ill_pht        0.0012      0.000      4.124      0.000       0.001       0.002
# dvisits_pht         -1.584e-05   6.08e-06     -2.606      0.010   -2.78e-05   -3.88e-06
# ndoctors_pht            0.0457      0.023      1.960      0.051      -0.000       0.092
# nсt_pht                 6.2530      3.358      1.862      0.064      -0.356      12.862
# ndiaglab_pht           -0.9826      0.456     -2.155      0.032      -1.880      -0.085
# nbacter_pht            -6.3003      2.171     -2.902      0.004     -10.573      -2.028
# nbiochem_pht           13.7578      6.325      2.175      0.030       1.311      26.204
# ncyto_pht               9.7878      5.097      1.920      0.056      -0.243      19.819
# nimun_pht             -28.2910      5.864     -4.824      0.000     -39.832     -16.750
# nphysic_pht             1.0512      0.477      2.205      0.028       0.113       1.990
# ndialysis_pht          -7.2103      3.578     -2.015      0.045     -14.253      -0.168
# air_pollution          -0.0231      0.005     -4.449      0.000      -0.033      -0.013
# polluted_dumps          0.0221      0.009      2.409      0.017       0.004       0.040
# num_clearing_plants     0.0168      0.005      3.535      0.000       0.007       0.026
# population_pht       6.873e-05   2.89e-05      2.375      0.018    1.18e-05       0.000
# ==============================================================================
# Omnibus:                      101.570   Durbin-Watson:                   1.877
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              391.140
# Skew:                           1.350   Prob(JB):                     1.16e-85
# Kurtosis:                       7.754   Cond. No.                     8.83e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.83e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
st_df.dvisits_pht.mean(), st_df.dvisits_pht.std()
# Out:
# (np.float64(453315.0943923567), np.float64(171419.2128427116))

# %%
st_df.insitu_pti.mean(), st_df.insitu_pti.std()
# Out:
# (np.float64(10.883736282298965), np.float64(7.7783324683339705))
