# %%
import ipywidgets as widgets
from IPython.display import display

import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.api as sm

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Data

# %% [markdown]
# ## Age group dataset

# %%
ag_df = pd.read_csv("./final_dataset/age_group_incidence.csv")
# Out:
# /tmp/ipykernel_117785/3917080270.py:1: DtypeWarning: Columns (32,33,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   ag_df = pd.read_csv("./final_dataset/age_group_incidence.csv")

# %%
ag_df.dtypes
# Out:
# year                          int64
# category                     object
# region                       object
# age_group                    object
# incidence                   float64
# nhospotal                   float64
# nbeds                       float64
# ybeds                       float64
# nill                        float64
# nvillage_ill                float64
# bed_days                    float64
# dvisits                     float64
# hvisits                     float64
# ndoctors                    float64
# nnursing                    float64
# nx_ray                      float64
# nflurography                float64
# nradiology                  float64
# nradlab                     float64
# nсt                         float64
# ncardiogram                 float64
# ndiaglab                    float64
# nbacter                     float64
# nbiochem                    float64
# ncyto                       float64
# nimun                       float64
# nphysic                     float64
# nendoscop                   float64
# nultrasound                 float64
# ndialysis                   float64
# gdp                         float64
# air_pollution               float64
# polluted_dumps               object
# not_cleaned_dumps            object
# dumps_not_cleaned_enough     object
# num_clearing_plants         float64
# cpi                         float64
# population                  float64
# dtype: object

# %%
ag_df.head()
# Out:
#    year                                           category             region  \
# 0  2008  Злоякiснi новоутворення-всього         C00-C97...  Івано-Франківська
# 1  2008  Злоякiснi новоутворення-всього         C00-C97...  Івано-Франківська
# 2  2008  Злоякiснi новоутворення-всього         C00-C97...  Івано-Франківська
# 3  2008  Злоякiснi новоутворення-всього         C00-C97...  Івано-Франківська
# 4  2008  Злоякiснi новоутворення-всього         C00-C97...  Івано-Франківська
#
#   age_group  incidence  nhospotal    nbeds    ybeds      nill  nvillage_ill  \
# 0   до 1 р.        1.0       63.0  10786.0  10786.0  302630.0      172379.0
# 1   до 1 р.        1.0       63.0  10786.0  10786.0  302630.0      172379.0
# 2   до 1 р.        1.0       63.0  10786.0  10786.0  302630.0      172379.0
# 3    1-4 р.        0.0       63.0  10786.0  10786.0  302630.0      172379.0
# 4    1-4 р.        0.0       63.0  10786.0  10786.0  302630.0      172379.0
#
#    ...  nultrasound  ndialysis      gdp  air_pollution  polluted_dumps  \
# 0  ...         52.0        5.0  12940.0          241.7              19
# 1  ...         52.0        5.0  12940.0          241.7              19
# 2  ...         52.0        5.0  12940.0          241.7              19
# 3  ...         52.0        5.0  12940.0          241.7              19
# 4  ...         52.0        5.0  12940.0          241.7              19
#
#    not_cleaned_dumps  dumps_not_cleaned_enough  num_clearing_plants    cpi  \
# 0                  0                       NaN                131.0  122.3
# 1                  0                       NaN                131.0  122.3
# 2                  0                       NaN                131.0  122.3
# 3                  0                       NaN                131.0  122.3
# 4                  0                       NaN                131.0  122.3
#
#    population
# 0   1382603.0
# 1   1382603.0
# 2   1382603.0
# 3   1382603.0
# 4   1382603.0
#
# [5 rows x 38 columns]

# %%
ag_df = ag_df.dropna()

# %% [markdown]
# ### Regions

# %%
regions = ag_df.region.unique()

regions
# Out:
# array(['Івано-Франківська', 'Волинська', 'Вінницька', 'Дніпропетровська',
#        'Донецька', 'Житомирська', 'Закарпатська', 'Запорізька',
#        'Київська', 'Кіровоградська', 'Луганська', 'Львівська',
#        'Миколаївська', 'Одеська', 'Полтавська', 'Рівненська', 'Сумська',
#        'Тернопільська', 'Харківська', 'Херсонська', 'Хмельницька',
#        'Черкаська', 'Чернівецька', 'Чернігівська'], dtype=object)

# %% [markdown]
# ### Age groups

# %%
age_groups = ag_df.age_group.unique()

age_groups
# Out:
# array(['до 1 р.', '1-4 р.', '5-9 р.', '10-14р', '15-19р', 'в т.ч. 15-17р',
#        '20-24р', '25-29р', '30-34р', '35-39р', '40-44р', '45-49р',
#        '50-54р', '55-59р', '60-64р', '65-69р', '70-74р', '75-79р',
#        '80-84р', '85 та старші'], dtype=object)

# %% [markdown]
# ### Region-age groups combinations:

# %%
models_data_groups = list(itertools.product(age_groups, regions))

models_data_groups
# Out:
# [('до 1 р.', 'Івано-Франківська'),
#  ('до 1 р.', 'Волинська'),
#  ('до 1 р.', 'Вінницька'),
#  ('до 1 р.', 'Дніпропетровська'),
#  ('до 1 р.', 'Донецька'),
#  ('до 1 р.', 'Житомирська'),
#  ('до 1 р.', 'Закарпатська'),
#  ('до 1 р.', 'Запорізька'),
#  ('до 1 р.', 'Київська'),
#  ('до 1 р.', 'Кіровоградська'),
#  ('до 1 р.', 'Луганська'),
#  ('до 1 р.', 'Львівська'),
#  ('до 1 р.', 'Миколаївська'),
#  ('до 1 р.', 'Одеська'),
#  ('до 1 р.', 'Полтавська'),
#  ('до 1 р.', 'Рівненська'),
#  ('до 1 р.', 'Сумська'),
#  ('до 1 р.', 'Тернопільська'),
#  ('до 1 р.', 'Харківська'),
#  ('до 1 р.', 'Херсонська'),
#  ('до 1 р.', 'Хмельницька'),
#  ('до 1 р.', 'Черкаська'),
#  ('до 1 р.', 'Чернівецька'),
#  ('до 1 р.', 'Чернігівська'),
#  ('1-4 р.', 'Івано-Франківська'),
#  ('1-4 р.', 'Волинська'),
#  ('1-4 р.', 'Вінницька'),
#  ('1-4 р.', 'Дніпропетровська'),
#  ('1-4 р.', 'Донецька'),
#  ('1-4 р.', 'Житомирська'),
#  ('1-4 р.', 'Закарпатська'),
#  ('1-4 р.', 'Запорізька'),
#  ('1-4 р.', 'Київська'),
#  ('1-4 р.', 'Кіровоградська'),
#  ('1-4 р.', 'Луганська'),
#  ('1-4 р.', 'Львівська'),
#  ('1-4 р.', 'Миколаївська'),
#  ('1-4 р.', 'Одеська'),
#  ('1-4 р.', 'Полтавська'),
#  ('1-4 р.', 'Рівненська'),
#  ('1-4 р.', 'Сумська'),
#  ('1-4 р.', 'Тернопільська'),
#  ('1-4 р.', 'Харківська'),
#  ('1-4 р.', 'Херсонська'),
#  ('1-4 р.', 'Хмельницька'),
#  ('1-4 р.', 'Черкаська'),
#  ('1-4 р.', 'Чернівецька'),
#  ('1-4 р.', 'Чернігівська'),
#  ('5-9 р.', 'Івано-Франківська'),
#  ('5-9 р.', 'Волинська'),
#  ('5-9 р.', 'Вінницька'),
#  ('5-9 р.', 'Дніпропетровська'),
#  ('5-9 р.', 'Донецька'),
#  ('5-9 р.', 'Житомирська'),
#  ('5-9 р.', 'Закарпатська'),
#  ('5-9 р.', 'Запорізька'),
#  ('5-9 р.', 'Київська'),
#  ('5-9 р.', 'Кіровоградська'),
#  ('5-9 р.', 'Луганська'),
#  ('5-9 р.', 'Львівська'),
#  ('5-9 р.', 'Миколаївська'),
#  ('5-9 р.', 'Одеська'),
#  ('5-9 р.', 'Полтавська'),
#  ('5-9 р.', 'Рівненська'),
#  ('5-9 р.', 'Сумська'),
#  ('5-9 р.', 'Тернопільська'),
#  ('5-9 р.', 'Харківська'),
#  ('5-9 р.', 'Херсонська'),
#  ('5-9 р.', 'Хмельницька'),
#  ('5-9 р.', 'Черкаська'),
#  ('5-9 р.', 'Чернівецька'),
#  ('5-9 р.', 'Чернігівська'),
#  ('10-14р', 'Івано-Франківська'),
#  ('10-14р', 'Волинська'),
#  ('10-14р', 'Вінницька'),
#  ('10-14р', 'Дніпропетровська'),
#  ('10-14р', 'Донецька'),
#  ('10-14р', 'Житомирська'),
#  ('10-14р', 'Закарпатська'),
#  ('10-14р', 'Запорізька'),
#  ('10-14р', 'Київська'),
#  ('10-14р', 'Кіровоградська'),
#  ('10-14р', 'Луганська'),
#  ('10-14р', 'Львівська'),
#  ('10-14р', 'Миколаївська'),
#  ('10-14р', 'Одеська'),
#  ('10-14р', 'Полтавська'),
#  ('10-14р', 'Рівненська'),
#  ('10-14р', 'Сумська'),
#  ('10-14р', 'Тернопільська'),
#  ('10-14р', 'Харківська'),
#  ('10-14р', 'Херсонська'),
#  ('10-14р', 'Хмельницька'),
#  ('10-14р', 'Черкаська'),
#  ('10-14р', 'Чернівецька'),
#  ('10-14р', 'Чернігівська'),
#  ('15-19р', 'Івано-Франківська'),
#  ('15-19р', 'Волинська'),
#  ('15-19р', 'Вінницька'),
#  ('15-19р', 'Дніпропетровська'),
#  ('15-19р', 'Донецька'),
#  ('15-19р', 'Житомирська'),
#  ('15-19р', 'Закарпатська'),
#  ('15-19р', 'Запорізька'),
#  ('15-19р', 'Київська'),
#  ('15-19р', 'Кіровоградська'),
#  ('15-19р', 'Луганська'),
#  ('15-19р', 'Львівська'),
#  ('15-19р', 'Миколаївська'),
#  ('15-19р', 'Одеська'),
#  ('15-19р', 'Полтавська'),
#  ('15-19р', 'Рівненська'),
#  ('15-19р', 'Сумська'),
#  ('15-19р', 'Тернопільська'),
#  ('15-19р', 'Харківська'),
#  ('15-19р', 'Херсонська'),
#  ('15-19р', 'Хмельницька'),
#  ('15-19р', 'Черкаська'),
#  ('15-19р', 'Чернівецька'),
#  ('15-19р', 'Чернігівська'),
#  ('в т.ч. 15-17р', 'Івано-Франківська'),
#  ('в т.ч. 15-17р', 'Волинська'),
#  ('в т.ч. 15-17р', 'Вінницька'),
#  ('в т.ч. 15-17р', 'Дніпропетровська'),
#  ('в т.ч. 15-17р', 'Донецька'),
#  ('в т.ч. 15-17р', 'Житомирська'),
#  ('в т.ч. 15-17р', 'Закарпатська'),
#  ('в т.ч. 15-17р', 'Запорізька'),
#  ('в т.ч. 15-17р', 'Київська'),
#  ('в т.ч. 15-17р', 'Кіровоградська'),
#  ('в т.ч. 15-17р', 'Луганська'),
#  ('в т.ч. 15-17р', 'Львівська'),
#  ('в т.ч. 15-17р', 'Миколаївська'),
#  ('в т.ч. 15-17р', 'Одеська'),
#  ('в т.ч. 15-17р', 'Полтавська'),
#  ('в т.ч. 15-17р', 'Рівненська'),
#  ('в т.ч. 15-17р', 'Сумська'),
#  ('в т.ч. 15-17р', 'Тернопільська'),
#  ('в т.ч. 15-17р', 'Харківська'),
#  ('в т.ч. 15-17р', 'Херсонська'),
#  ('в т.ч. 15-17р', 'Хмельницька'),
#  ('в т.ч. 15-17р', 'Черкаська'),
#  ('в т.ч. 15-17р', 'Чернівецька'),
#  ('в т.ч. 15-17р', 'Чернігівська'),
#  ('20-24р', 'Івано-Франківська'),
#  ('20-24р', 'Волинська'),
#  ('20-24р', 'Вінницька'),
#  ('20-24р', 'Дніпропетровська'),
#  ('20-24р', 'Донецька'),
#  ('20-24р', 'Житомирська'),
#  ('20-24р', 'Закарпатська'),
#  ('20-24р', 'Запорізька'),
#  ('20-24р', 'Київська'),
#  ('20-24р', 'Кіровоградська'),
#  ('20-24р', 'Луганська'),
#  ('20-24р', 'Львівська'),
#  ('20-24р', 'Миколаївська'),
#  ('20-24р', 'Одеська'),
#  ('20-24р', 'Полтавська'),
#  ('20-24р', 'Рівненська'),
#  ('20-24р', 'Сумська'),
#  ('20-24р', 'Тернопільська'),
#  ('20-24р', 'Харківська'),
#  ('20-24р', 'Херсонська'),
#  ('20-24р', 'Хмельницька'),
#  ('20-24р', 'Черкаська'),
#  ('20-24р', 'Чернівецька'),
#  ('20-24р', 'Чернігівська'),
#  ('25-29р', 'Івано-Франківська'),
#  ('25-29р', 'Волинська'),
#  ('25-29р', 'Вінницька'),
#  ('25-29р', 'Дніпропетровська'),
#  ('25-29р', 'Донецька'),
#  ('25-29р', 'Житомирська'),
#  ('25-29р', 'Закарпатська'),
#  ('25-29р', 'Запорізька'),
#  ('25-29р', 'Київська'),
#  ('25-29р', 'Кіровоградська'),
#  ('25-29р', 'Луганська'),
#  ('25-29р', 'Львівська'),
#  ('25-29р', 'Миколаївська'),
#  ('25-29р', 'Одеська'),
#  ('25-29р', 'Полтавська'),
#  ('25-29р', 'Рівненська'),
#  ('25-29р', 'Сумська'),
#  ('25-29р', 'Тернопільська'),
#  ('25-29р', 'Харківська'),
#  ('25-29р', 'Херсонська'),
#  ('25-29р', 'Хмельницька'),
#  ('25-29р', 'Черкаська'),
#  ('25-29р', 'Чернівецька'),
#  ('25-29р', 'Чернігівська'),
#  ('30-34р', 'Івано-Франківська'),
#  ('30-34р', 'Волинська'),
#  ('30-34р', 'Вінницька'),
#  ('30-34р', 'Дніпропетровська'),
#  ('30-34р', 'Донецька'),
#  ('30-34р', 'Житомирська'),
#  ('30-34р', 'Закарпатська'),
#  ('30-34р', 'Запорізька'),
#  ('30-34р', 'Київська'),
#  ('30-34р', 'Кіровоградська'),
#  ('30-34р', 'Луганська'),
#  ('30-34р', 'Львівська'),
#  ('30-34р', 'Миколаївська'),
#  ('30-34р', 'Одеська'),
#  ('30-34р', 'Полтавська'),
#  ('30-34р', 'Рівненська'),
#  ('30-34р', 'Сумська'),
#  ('30-34р', 'Тернопільська'),
#  ('30-34р', 'Харківська'),
#  ('30-34р', 'Херсонська'),
#  ('30-34р', 'Хмельницька'),
#  ('30-34р', 'Черкаська'),
#  ('30-34р', 'Чернівецька'),
#  ('30-34р', 'Чернігівська'),
#  ('35-39р', 'Івано-Франківська'),
#  ('35-39р', 'Волинська'),
#  ('35-39р', 'Вінницька'),
#  ('35-39р', 'Дніпропетровська'),
#  ('35-39р', 'Донецька'),
#  ('35-39р', 'Житомирська'),
#  ('35-39р', 'Закарпатська'),
#  ('35-39р', 'Запорізька'),
#  ('35-39р', 'Київська'),
#  ('35-39р', 'Кіровоградська'),
#  ('35-39р', 'Луганська'),
#  ('35-39р', 'Львівська'),
#  ('35-39р', 'Миколаївська'),
#  ('35-39р', 'Одеська'),
#  ('35-39р', 'Полтавська'),
#  ('35-39р', 'Рівненська'),
#  ('35-39р', 'Сумська'),
#  ('35-39р', 'Тернопільська'),
#  ('35-39р', 'Харківська'),
#  ('35-39р', 'Херсонська'),
#  ('35-39р', 'Хмельницька'),
#  ('35-39р', 'Черкаська'),
#  ('35-39р', 'Чернівецька'),
#  ('35-39р', 'Чернігівська'),
#  ('40-44р', 'Івано-Франківська'),
#  ('40-44р', 'Волинська'),
#  ('40-44р', 'Вінницька'),
#  ('40-44р', 'Дніпропетровська'),
#  ('40-44р', 'Донецька'),
#  ('40-44р', 'Житомирська'),
#  ('40-44р', 'Закарпатська'),
#  ('40-44р', 'Запорізька'),
#  ('40-44р', 'Київська'),
#  ('40-44р', 'Кіровоградська'),
#  ('40-44р', 'Луганська'),
#  ('40-44р', 'Львівська'),
#  ('40-44р', 'Миколаївська'),
#  ('40-44р', 'Одеська'),
#  ('40-44р', 'Полтавська'),
#  ('40-44р', 'Рівненська'),
#  ('40-44р', 'Сумська'),
#  ('40-44р', 'Тернопільська'),
#  ('40-44р', 'Харківська'),
#  ('40-44р', 'Херсонська'),
#  ('40-44р', 'Хмельницька'),
#  ('40-44р', 'Черкаська'),
#  ('40-44р', 'Чернівецька'),
#  ('40-44р', 'Чернігівська'),
#  ('45-49р', 'Івано-Франківська'),
#  ('45-49р', 'Волинська'),
#  ('45-49р', 'Вінницька'),
#  ('45-49р', 'Дніпропетровська'),
#  ('45-49р', 'Донецька'),
#  ('45-49р', 'Житомирська'),
#  ('45-49р', 'Закарпатська'),
#  ('45-49р', 'Запорізька'),
#  ('45-49р', 'Київська'),
#  ('45-49р', 'Кіровоградська'),
#  ('45-49р', 'Луганська'),
#  ('45-49р', 'Львівська'),
#  ('45-49р', 'Миколаївська'),
#  ('45-49р', 'Одеська'),
#  ('45-49р', 'Полтавська'),
#  ('45-49р', 'Рівненська'),
#  ('45-49р', 'Сумська'),
#  ('45-49р', 'Тернопільська'),
#  ('45-49р', 'Харківська'),
#  ('45-49р', 'Херсонська'),
#  ('45-49р', 'Хмельницька'),
#  ('45-49р', 'Черкаська'),
#  ('45-49р', 'Чернівецька'),
#  ('45-49р', 'Чернігівська'),
#  ('50-54р', 'Івано-Франківська'),
#  ('50-54р', 'Волинська'),
#  ('50-54р', 'Вінницька'),
#  ('50-54р', 'Дніпропетровська'),
#  ('50-54р', 'Донецька'),
#  ('50-54р', 'Житомирська'),
#  ('50-54р', 'Закарпатська'),
#  ('50-54р', 'Запорізька'),
#  ('50-54р', 'Київська'),
#  ('50-54р', 'Кіровоградська'),
#  ('50-54р', 'Луганська'),
#  ('50-54р', 'Львівська'),
#  ('50-54р', 'Миколаївська'),
#  ('50-54р', 'Одеська'),
#  ('50-54р', 'Полтавська'),
#  ('50-54р', 'Рівненська'),
#  ('50-54р', 'Сумська'),
#  ('50-54р', 'Тернопільська'),
#  ('50-54р', 'Харківська'),
#  ('50-54р', 'Херсонська'),
#  ('50-54р', 'Хмельницька'),
#  ('50-54р', 'Черкаська'),
#  ('50-54р', 'Чернівецька'),
#  ('50-54р', 'Чернігівська'),
#  ('55-59р', 'Івано-Франківська'),
#  ('55-59р', 'Волинська'),
#  ('55-59р', 'Вінницька'),
#  ('55-59р', 'Дніпропетровська'),
#  ('55-59р', 'Донецька'),
#  ('55-59р', 'Житомирська'),
#  ('55-59р', 'Закарпатська'),
#  ('55-59р', 'Запорізька'),
#  ('55-59р', 'Київська'),
#  ('55-59р', 'Кіровоградська'),
#  ('55-59р', 'Луганська'),
#  ('55-59р', 'Львівська'),
#  ('55-59р', 'Миколаївська'),
#  ('55-59р', 'Одеська'),
#  ('55-59р', 'Полтавська'),
#  ('55-59р', 'Рівненська'),
#  ('55-59р', 'Сумська'),
#  ('55-59р', 'Тернопільська'),
#  ('55-59р', 'Харківська'),
#  ('55-59р', 'Херсонська'),
#  ('55-59р', 'Хмельницька'),
#  ('55-59р', 'Черкаська'),
#  ('55-59р', 'Чернівецька'),
#  ('55-59р', 'Чернігівська'),
#  ('60-64р', 'Івано-Франківська'),
#  ('60-64р', 'Волинська'),
#  ('60-64р', 'Вінницька'),
#  ('60-64р', 'Дніпропетровська'),
#  ('60-64р', 'Донецька'),
#  ('60-64р', 'Житомирська'),
#  ('60-64р', 'Закарпатська'),
#  ('60-64р', 'Запорізька'),
#  ('60-64р', 'Київська'),
#  ('60-64р', 'Кіровоградська'),
#  ('60-64р', 'Луганська'),
#  ('60-64р', 'Львівська'),
#  ('60-64р', 'Миколаївська'),
#  ('60-64р', 'Одеська'),
#  ('60-64р', 'Полтавська'),
#  ('60-64р', 'Рівненська'),
#  ('60-64р', 'Сумська'),
#  ('60-64р', 'Тернопільська'),
#  ('60-64р', 'Харківська'),
#  ('60-64р', 'Херсонська'),
#  ('60-64р', 'Хмельницька'),
#  ('60-64р', 'Черкаська'),
#  ('60-64р', 'Чернівецька'),
#  ('60-64р', 'Чернігівська'),
#  ('65-69р', 'Івано-Франківська'),
#  ('65-69р', 'Волинська'),
#  ('65-69р', 'Вінницька'),
#  ('65-69р', 'Дніпропетровська'),
#  ('65-69р', 'Донецька'),
#  ('65-69р', 'Житомирська'),
#  ('65-69р', 'Закарпатська'),
#  ('65-69р', 'Запорізька'),
#  ('65-69р', 'Київська'),
#  ('65-69р', 'Кіровоградська'),
#  ('65-69р', 'Луганська'),
#  ('65-69р', 'Львівська'),
#  ('65-69р', 'Миколаївська'),
#  ('65-69р', 'Одеська'),
#  ('65-69р', 'Полтавська'),
#  ('65-69р', 'Рівненська'),
#  ('65-69р', 'Сумська'),
#  ('65-69р', 'Тернопільська'),
#  ('65-69р', 'Харківська'),
#  ('65-69р', 'Херсонська'),
#  ('65-69р', 'Хмельницька'),
#  ('65-69р', 'Черкаська'),
#  ('65-69р', 'Чернівецька'),
#  ('65-69р', 'Чернігівська'),
#  ('70-74р', 'Івано-Франківська'),
#  ('70-74р', 'Волинська'),
#  ('70-74р', 'Вінницька'),
#  ('70-74р', 'Дніпропетровська'),
#  ('70-74р', 'Донецька'),
#  ('70-74р', 'Житомирська'),
#  ('70-74р', 'Закарпатська'),
#  ('70-74р', 'Запорізька'),
#  ('70-74р', 'Київська'),
#  ('70-74р', 'Кіровоградська'),
#  ('70-74р', 'Луганська'),
#  ('70-74р', 'Львівська'),
#  ('70-74р', 'Миколаївська'),
#  ('70-74р', 'Одеська'),
#  ('70-74р', 'Полтавська'),
#  ('70-74р', 'Рівненська'),
#  ('70-74р', 'Сумська'),
#  ('70-74р', 'Тернопільська'),
#  ('70-74р', 'Харківська'),
#  ('70-74р', 'Херсонська'),
#  ('70-74р', 'Хмельницька'),
#  ('70-74р', 'Черкаська'),
#  ('70-74р', 'Чернівецька'),
#  ('70-74р', 'Чернігівська'),
#  ('75-79р', 'Івано-Франківська'),
#  ('75-79р', 'Волинська'),
#  ('75-79р', 'Вінницька'),
#  ('75-79р', 'Дніпропетровська'),
#  ('75-79р', 'Донецька'),
#  ('75-79р', 'Житомирська'),
#  ('75-79р', 'Закарпатська'),
#  ('75-79р', 'Запорізька'),
#  ('75-79р', 'Київська'),
#  ('75-79р', 'Кіровоградська'),
#  ('75-79р', 'Луганська'),
#  ('75-79р', 'Львівська'),
#  ('75-79р', 'Миколаївська'),
#  ('75-79р', 'Одеська'),
#  ('75-79р', 'Полтавська'),
#  ('75-79р', 'Рівненська'),
#  ('75-79р', 'Сумська'),
#  ('75-79р', 'Тернопільська'),
#  ('75-79р', 'Харківська'),
#  ('75-79р', 'Херсонська'),
#  ('75-79р', 'Хмельницька'),
#  ('75-79р', 'Черкаська'),
#  ('75-79р', 'Чернівецька'),
#  ('75-79р', 'Чернігівська'),
#  ('80-84р', 'Івано-Франківська'),
#  ('80-84р', 'Волинська'),
#  ('80-84р', 'Вінницька'),
#  ('80-84р', 'Дніпропетровська'),
#  ('80-84р', 'Донецька'),
#  ('80-84р', 'Житомирська'),
#  ('80-84р', 'Закарпатська'),
#  ('80-84р', 'Запорізька'),
#  ('80-84р', 'Київська'),
#  ('80-84р', 'Кіровоградська'),
#  ('80-84р', 'Луганська'),
#  ('80-84р', 'Львівська'),
#  ('80-84р', 'Миколаївська'),
#  ('80-84р', 'Одеська'),
#  ('80-84р', 'Полтавська'),
#  ('80-84р', 'Рівненська'),
#  ('80-84р', 'Сумська'),
#  ('80-84р', 'Тернопільська'),
#  ('80-84р', 'Харківська'),
#  ('80-84р', 'Херсонська'),
#  ('80-84р', 'Хмельницька'),
#  ('80-84р', 'Черкаська'),
#  ('80-84р', 'Чернівецька'),
#  ('80-84р', 'Чернігівська'),
#  ('85 та старші', 'Івано-Франківська'),
#  ('85 та старші', 'Волинська'),
#  ('85 та старші', 'Вінницька'),
#  ('85 та старші', 'Дніпропетровська'),
#  ('85 та старші', 'Донецька'),
#  ('85 та старші', 'Житомирська'),
#  ('85 та старші', 'Закарпатська'),
#  ('85 та старші', 'Запорізька'),
#  ('85 та старші', 'Київська'),
#  ('85 та старші', 'Кіровоградська'),
#  ('85 та старші', 'Луганська'),
#  ('85 та старші', 'Львівська'),
#  ('85 та старші', 'Миколаївська'),
#  ('85 та старші', 'Одеська'),
#  ('85 та старші', 'Полтавська'),
#  ('85 та старші', 'Рівненська'),
#  ('85 та старші', 'Сумська'),
#  ('85 та старші', 'Тернопільська'),
#  ('85 та старші', 'Харківська'),
#  ('85 та старші', 'Херсонська'),
#  ('85 та старші', 'Хмельницька'),
#  ('85 та старші', 'Черкаська'),
#  ('85 та старші', 'Чернівецька'),
#  ('85 та старші', 'Чернігівська')]

# %% [markdown]
# ### Cancer statistics categories

# %%
all_categories = list(ag_df.category.unique())

total_male_category = "Злоякiснi новоутворення-всього         C00-C97    ч"
total_female_category = "C00-C97    ж"

localization_categories = all_categories.copy()
localization_categories.remove(total_male_category)
localization_categories.remove(total_female_category)

male_localization_categories = [category for category in localization_categories if category.endswith('ч')]
female_localization_categories = [category for category in localization_categories if category.endswith('ж')]

# %% [markdown]
# ## Stage dataset

# %%
st_df = pd.read_csv("./final_dataset/stage_incidence.csv")

st_df["age_group"] = "all"
st_df['category'] = "all"

st_df = st_df.dropna()

st_df.head()
# Out:
#     year             region  mtumors  syncmtumors  insitu  ncervix  nhospotal  \
# 72  2009  Івано-Франківська    130.0         24.0    25.0     17.0       64.0
# 73  2009          Волинська    169.0         52.0    56.0     52.0       52.0
# 74  2009          Вінницька    343.0        102.0   115.0     93.0      109.0
# 75  2009   Дніпропетровська    724.0        196.0   200.0    156.0      159.0
# 76  2009           Донецька    839.0        200.0    38.0     24.0      177.0
#
#       nbeds    ybeds      nill  ...      gdp  air_pollution  polluted_dumps  \
# 72  10711.0  10757.0  297544.0  ...  12485.0          214.5              17
# 73   7653.0   7655.0  227604.0  ...  11796.0            7.6               4
# 74  12460.0  12499.0  363456.0  ...  12145.0          114.3               2
# 75  30175.0  30491.0  791550.0  ...  27737.0          792.1             522
# 76  32360.0  32551.0  883624.0  ...  23137.0         1299.8             531
#
#     not_cleaned_dumps  dumps_not_cleaned_enough  num_clearing_plants    cpi  \
# 72                  0                        17                133.0  112.3
# 73                  1                         3                 78.0  112.3
# 74                  0                         2                 98.0  112.3
# 75                124                       398                970.0  112.3
# 76                 17                       514               1570.0  112.3
#
#     population  age_group  category
# 72   1381062.0        all       all
# 73   1036221.0        all       all
# 74   1659975.0        all       all
# 75   3374228.0        all       all
# 76   4500477.0        all       all
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Feature engineering

# %%
ag_df.columns
# Out:
# Index(['year', 'category', 'region', 'age_group', 'incidence', 'nhospotal',
#        'nbeds', 'ybeds', 'nill', 'nvillage_ill', 'bed_days', 'dvisits',
#        'hvisits', 'ndoctors', 'nnursing', 'nx_ray', 'nflurography',
#        'nradiology', 'nradlab', 'nсt', 'ncardiogram', 'ndiaglab', 'nbacter',
#        'nbiochem', 'ncyto', 'nimun', 'nphysic', 'nendoscop', 'nultrasound',
#        'ndialysis', 'gdp', 'air_pollution', 'polluted_dumps',
#        'not_cleaned_dumps', 'dumps_not_cleaned_enough', 'num_clearing_plants',
#        'cpi', 'population'],
#       dtype='object')

# %%
population_related_columns = ['incidence', 'nhospotal', 'nbeds', 'ybeds', 'nill', 'nvillage_ill', 'bed_days', 'dvisits', 
                              'hvisits', 'ndoctors', 'nnursing', 'nx_ray', 'nflurography', 'nradiology', 'nradlab',
                              'nсt', 'ncardiogram', 'ndiaglab', 'nbacter', 'nbiochem', 'ncyto', 'nimun', 'nphysic', 
                              'nendoscop', 'nultrasound','ndialysis']

# population_hundreds = ag_df.population / 100

# # for col in population_related_columns:
# #     ag_df[col] = ag_df[col] / population_hundreds

# ag_df[ag_df.region == "Дніпропетровська"].population
# Out:
#         year                                           category  \
# 162720  2009  Злоякiснi новоутворення-всього         C00-C97...
# 162721  2009  Злоякiснi новоутворення-всього         C00-C97...
# 162722  2009  Злоякiснi новоутворення-всього         C00-C97...
# 162723  2009  Злоякiснi новоутворення-всього         C00-C97...
# 162724  2009  Злоякiснi новоутворення-всього         C00-C97...
#
#                    region age_group  incidence  nhospotal    nbeds    ybeds  \
# 162720  Івано-Франківська   до 1 р.        1.0       64.0  10711.0  10757.0
# 162721  Івано-Франківська    1-4 р.        1.0       64.0  10711.0  10757.0
# 162722  Івано-Франківська    5-9 р.        2.0       64.0  10711.0  10757.0
# 162723  Івано-Франківська    10-14р        5.0       64.0  10711.0  10757.0
# 162724  Івано-Франківська    15-19р        6.0       64.0  10711.0  10757.0
#
#             nill  nvillage_ill  ...  nultrasound  ndialysis      gdp  \
# 162720  297544.0      170065.0  ...         55.0        4.0  12485.0
# 162721  297544.0      170065.0  ...         55.0        4.0  12485.0
# 162722  297544.0      170065.0  ...         55.0        4.0  12485.0
# 162723  297544.0      170065.0  ...         55.0        4.0  12485.0
# 162724  297544.0      170065.0  ...         55.0        4.0  12485.0
#
#         air_pollution  polluted_dumps  not_cleaned_dumps  \
# 162720          214.5              17                  0
# 162721          214.5              17                  0
# 162722          214.5              17                  0
# 162723          214.5              17                  0
# 162724          214.5              17                  0
#
#         dumps_not_cleaned_enough  num_clearing_plants    cpi  population
# 162720                      17.0                133.0  112.3   1381062.0
# 162721                      17.0                133.0  112.3   1381062.0
# 162722                      17.0                133.0  112.3   1381062.0
# 162723                      17.0                133.0  112.3   1381062.0
# 162724                      17.0                133.0  112.3   1381062.0
#
# [5 rows x 38 columns]

# %%
population_related_columns = ['nhospotal', 'nbeds', 'ybeds', 'nill', 'nvillage_ill', 'bed_days', 'dvisits', 
                              'hvisits', 'ndoctors', 'nnursing', 'nx_ray', 'nflurography', 'nradiology', 'nradlab',
                              'nсt', 'ncardiogram', 'ndiaglab', 'nbacter', 'nbiochem', 'ncyto', 'nimun', 'nphysic', 
                              'nendoscop', 'nultrasound','ndialysis', "mtumors", "insitu"]

population_hundreds = st_df.population / 100

for col in population_related_columns:
    st_df[col] = st_df[col] / population_hundreds

total_incidence_df = ag_df[ag_df.category.isin([total_female_category, total_male_category])].groupby(['year', 'region']).agg({'incidence': 'sum'}).reset_index()


st_df.head()
# Out:
#     year             region   mtumors  syncmtumors    insitu  ncervix  \
# 72  2009  Івано-Франківська  0.009413         24.0  0.001810     17.0
# 73  2009          Волинська  0.016309         52.0  0.005404     52.0
# 74  2009          Вінницька  0.020663        102.0  0.006928     93.0
# 75  2009   Дніпропетровська  0.021457        196.0  0.005927    156.0
# 76  2009           Донецька  0.018642        200.0  0.000844     24.0
#
#     nhospotal     nbeds     ybeds       nill  ...      gdp  air_pollution  \
# 72   0.004634  0.775563  0.778893  21.544579  ...  12485.0          214.5
# 73   0.005018  0.738549  0.738742  21.964813  ...  11796.0            7.6
# 74   0.006566  0.750614  0.752963  21.895270  ...  12145.0          114.3
# 75   0.004712  0.894279  0.903644  23.458699  ...  27737.0          792.1
# 76   0.003933  0.719035  0.723279  19.634008  ...  23137.0         1299.8
#
#     polluted_dumps  not_cleaned_dumps  dumps_not_cleaned_enough  \
# 72              17                  0                        17
# 73               4                  1                         3
# 74               2                  0                         2
# 75             522                124                       398
# 76             531                 17                       514
#
#     num_clearing_plants    cpi  population  age_group  category
# 72                133.0  112.3   1381062.0        all       all
# 73                 78.0  112.3   1036221.0        all       all
# 74                 98.0  112.3   1659975.0        all       all
# 75                970.0  112.3   3374228.0        all       all
# 76               1570.0  112.3   4500477.0        all       all
#
# [5 rows x 41 columns]

# %% [markdown]
# # Model selection

# %%
def select_best_model_for(df: pd.DataFrame, target: str, ommit: list[str]) -> tuple[sm.OLS, list[str]]:
    predictors = df.drop(columns=ommit + [target], errors="ignore")

    predictors = predictors.select_dtypes(include=["number"])
    
    X = predictors.copy()
    y = df[target]
    
    X = sm.add_constant(X)
    
    best_model = sm.OLS(y, X).fit()

    best_aic = np.inf

    to_drop = None

    while len(X.columns) > 0:
        aic_not_changed = True
            
        for col in X.columns:
            temp_X = X.drop(col, axis = 1)
            temp_model = sm.OLS(y, temp_X).fit()
            if temp_model.aic < best_aic:
                best_aic = temp_model.aic
                best_model = temp_model
                to_drop = col
                aic_not_changed = False

        if aic_not_changed:
            break

        X = X.drop(to_drop, axis = 1)
    
    return best_model

# %%
class Model:

    def __init__(self, name: str, ols: sm.OLS, identifier: tuple[str]):
        self.name = name
        self.ols = ols
        self.identifier = identifier

    def display_summary(self):
        original_summary = str(self.ols.summary())
        without_title = '\n'.join(original_summary.split('\n')[1:])
        new_summary = f"{self.name:^78}\n"
        new_summary += f"{"Category:":<{20}} {self.identifier[0]:>{57}}\n"
        new_summary += f"{"Region:":<{20}} {self.identifier[1]:>{57}}\n"
        new_summary += f"{"Age group:":<{20}} {self.identifier[2]:>{57}}\n"
        new_summary += without_title
        print(new_summary)

    def get_df(self, df: pd.DataFrame):
        category, region, age_group = self.identifier

        if category == '__all__':
            mask = (df.region == region) & (df.age_group == age_group)
        elif region == '__all__':
            mask = (df.category == category) & (df.age_group == age_group)
        elif age_group == '__all__':
            mask = (df.category == category) & (df.region == region)
        else:
            mask = (df.category == category) & (df.region == region) & (df.age_group == age_group)

        return df[mask]


def filter_models(models: dict[tuple, Model], categories: list[str] = None, regions: list[str] = None, age_groups: list[str] = None):
    filtered_models = []
    for model_identifier, model in models.items():
        category, region, age_group = model_identifier
        if categories and category not in categories:
            continue

        if regions and region not in regions:
            continue
        
        if age_groups and age_group not in age_groups:
            continue
            
        filtered_models.append(model)

    return filtered_models

# %% [markdown]
# ### Level-level models

# %%
import multiprocessing
import multiprocessing.queues

def worker(queue, models_identifiers, target, ommit, df):
    for category, region, age_group in models_identifiers:

        if category == '__all__':
            mask = (df.region == region) & (df.age_group == age_group)
        elif region == '__all__':
            mask = (df.category == category) & (df.age_group == age_group)
        elif age_group == '__all__':
            mask = (df.category == category) & (df.region == region)
        else:
            mask = (df.category == category) & (df.region == region) & (df.age_group == age_group)

        filtered_df = df[mask]
        best_model = select_best_model_for(filtered_df, target, ommit)
        model_identifier = (category, region, age_group)
        model = Model(f"Level-level Incidence model", 
                        ols=best_model,
                        identifier=model_identifier)
        queue.put(((category, region, age_group), model ))

def create_models_for(categories: list[str],
                      regions: list[str],
                      age_groups: list[str], 
                      df: pd.DataFrame,
                      target: str,
                      ommit: list,
                      njobs: int = 4) -> dict[tuple, Model]:
    models = {}

    progress = widgets.FloatProgress(value=0, min=0, max=len(regions)*len(age_groups), step=1)

    display(progress)

    model_identifiers = []

    for category in categories:
        for region in regions:
            for age_group in age_groups:
                model_identifiers.append((category, region, age_group))

    models_per_worker = len(model_identifiers) // njobs
    q = multiprocessing.Queue()
    processes = [ multiprocessing.Process(target=worker, args=(q, 
                                                               model_identifiers[i * models_per_worker: (i+1) * models_per_worker], 
                                                               target,
                                                               ommit,
                                                               df))
                                          for i in range(njobs) ]

    for p in processes:
        p.start()

    while any(p.is_alive() for p in processes) or not q.empty():
        try:
            identifier, model = q.get_nowait()
            models[identifier] = model
            progress.value += 1
        except multiprocessing.queues.Empty:
            pass


    return models

# %% [markdown]
# #### Male age region models

# %%
male_age_region_model = create_models_for(categories=[total_male_category],
                                         regions=regions,
                                         age_groups=age_groups,
                                         df=ag_df,
                                         target="incidence",
                                         ommit=["age_group", "year", "gdp", "region", "category"],
                                         njobs=12)
# Out:
# FloatProgress(value=0.0, max=480.0)

# %% [markdown]
# #### Female age region models

# %%
female_age_region_model = create_models_for(categories=[total_female_category],
                                            regions=regions,
                                            age_groups=age_groups,
                                            df=ag_df,
                                            target="incidence",
                                            ommit=["age_group", "year", "gdp", "region", "category"],
                                            njobs=12)
# Out:
# FloatProgress(value=0.0, max=480.0)

# %%
dnipro_models = filter_models(female_age_region_model, regions=['Дніпропетровська'])
dnipro_models[11].display_summary()
# Out:
#                          Level-level Incidence model
# Category:                                                         C00-C97    ж
# Region:                                                       Дніпропетровська
# Age group:                                                              45-49р
# ==============================================================================
# Dep. Variable:              incidence   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.400e+23
# Date:                Mon, 24 Mar 2025   Prob (F-statistic):           4.17e-24
# Time:                        19:23:42   Log-Likelihood:                 274.29
# No. Observations:                  12   AIC:                            -528.6
# Df Residuals:                       2   BIC:                            -523.7
# Df Model:                           9
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# nhospotal               0.0045   1.62e-14   2.78e+11      0.000       0.005       0.005
# nbeds                  -0.0639   1.77e-13  -3.61e+11      0.000      -0.064      -0.064
# ybeds                  -0.0678   2.46e-13  -2.76e+11      0.000      -0.068      -0.068
# nill                 8.137e-05   7.65e-15   1.06e+10      0.000    8.14e-05    8.14e-05
# nvillage_ill           -0.0061   2.47e-14  -2.46e+11      0.000      -0.006      -0.006
# bed_days                0.0002   9.58e-16   2.15e+11      0.000       0.000       0.000
# dvisits             -7.494e-05   3.27e-16  -2.29e+11      0.000   -7.49e-05   -7.49e-05
# hvisits                 0.0005   2.34e-15   2.26e+11      0.000       0.001       0.001
# ndoctors                0.2033   4.02e-13   5.06e+11      0.000       0.203       0.203
# nnursing               -0.0341   2.57e-13  -1.33e+11      0.000      -0.034      -0.034
# nx_ray                  0.0009    2.7e-14    3.2e+10      0.000       0.001       0.001
# nflurography           -0.0005    2.5e-14  -1.81e+10      0.000      -0.000      -0.000
# nradiology              0.0012   2.44e-15   4.83e+11      0.000       0.001       0.001
# nradlab              1.161e-06   6.02e-18   1.93e+11      0.000    1.16e-06    1.16e-06
# ncardiogram             0.0090    2.2e-14   4.08e+11      0.000       0.009       0.009
# ndiaglab                0.0078    2.7e-14   2.89e+11      0.000       0.008       0.008
# nbacter                -0.0003   8.47e-16  -3.09e+11      0.000      -0.000      -0.000
# nbiochem                0.0004   7.24e-15   5.07e+10      0.000       0.000       0.000
# ncyto                  -0.0003   2.05e-15  -1.54e+11      0.000      -0.000      -0.000
# nimun                   0.0008   5.31e-15   1.51e+11      0.000       0.001       0.001
# nphysic                 0.0029   6.04e-14   4.85e+10      0.000       0.003       0.003
# nendoscop              -0.0023   4.12e-15  -5.55e+11      0.000      -0.002      -0.002
# nultrasound            -0.0013   1.42e-14  -8.81e+10      0.000      -0.001      -0.001
# ndialysis              -0.0003   3.81e-15  -8.48e+10      0.000      -0.000      -0.000
# air_pollution           0.0557   7.79e-13   7.16e+10      0.000       0.056       0.056
# num_clearing_plants     0.0634   2.41e-13   2.63e+11      0.000       0.063       0.063
# cpi                    -0.0132   9.85e-14  -1.34e+11      0.000      -0.013      -0.013
# population              0.0007   2.18e-15   3.04e+11      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                       16.122   Durbin-Watson:                   1.313
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               10.887
# Skew:                           1.769   Prob(JB):                      0.00432
# Kurtosis:                       6.042   Cond. No.                     6.05e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The smallest eigenvalue is 1.19e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# /home/zhukowych/.virtualenvs/ml/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:418: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=12 observations were given.
#   return hypotest_fun_in(*args, **kwds)

# %%
dnipro_models[10].get_df(ag_df)
# Out:
#         year      category            region age_group  incidence  nhospotal  \
# 169530  2009  C00-C97    ж  Дніпропетровська    40-44р      230.0      159.0
# 223770  2010  C00-C97    ж  Дніпропетровська    40-44р      257.0      155.0
# 291630  2011  C00-C97    ж  Дніпропетровська    40-44р      297.0      110.0
# 291631  2011  C00-C97    ж  Дніпропетровська    40-44р      297.0      110.0
# 291632  2011  C00-C97    ж  Дніпропетровська    40-44р      297.0      110.0
# 440730  2012  C00-C97    ж  Дніпропетровська    40-44р      302.0      110.0
# 494994  2014  C00-C97    ж  Дніпропетровська    40-44р      265.0      104.0
# 549234  2015  C00-C97    ж  Дніпропетровська    40-44р      268.0      108.0
# 603474  2016  C00-C97    ж  Дніпропетровська    40-44р      272.0      105.0
# 657714  2017  C00-C97    ж  Дніпропетровська    40-44р      284.0      105.0
# 711954  2018  C00-C97    ж  Дніпропетровська    40-44р      292.0      104.0
# 766194  2019  C00-C97    ж  Дніпропетровська    40-44р      279.0      105.0
#
#           nbeds    ybeds      nill  nvillage_ill  ...  nultrasound  ndialysis  \
# 169530  30175.0  30491.0  791550.0      147829.0  ...        115.0        2.0
# 223770  29713.0  29892.0  805622.0      129025.0  ...        117.0        1.0
# 291630  25693.0  28121.0  775285.0      121457.0  ...        109.0        1.0
# 291631  25693.0  28121.0  775285.0      121457.0  ...        109.0        1.0
# 291632  25693.0  28121.0  775285.0      121457.0  ...        109.0        1.0
# 440730  25358.0  25390.0  739114.0      114355.0  ...        112.0        1.0
# 494994  24544.0  24589.0  726225.0      113976.0  ...        110.0        4.0
# 549234  24315.0  24535.0  729278.0      114261.0  ...        109.0        5.0
# 603474  23660.0  23806.0  726738.0      116876.0  ...        105.0        5.0
# 657714  23383.0  23447.0  712310.0      117917.0  ...        106.0        6.0
# 711954  23009.0  23154.0  694563.0      115861.0  ...        107.0        6.0
# 766194  22709.0  22855.0  678832.0      109834.0  ...        107.0        8.0
#
#              gdp  air_pollution  polluted_dumps  not_cleaned_dumps  \
# 169530   27737.0          792.1             522                124
# 223770   34709.0          933.1             504                133
# 291630   42068.0          950.4             472                138
# 291631   42068.0          950.4             472                138
# 291632   42068.0          950.4             472                138
# 440730   44650.0          962.0             383                132
# 494994   53749.0          855.8             312                119
# 549234   65897.0          723.9             267                115
# 603474   75396.0          833.0             244                102
# 657714   97043.0          657.3             230                230
# 711954  114750.0          614.3             234                234
# 766194  122298.0          576.9             200                200
#
#         dumps_not_cleaned_enough  num_clearing_plants    cpi  population
# 169530                       398                970.0  112.3   3374228.0
# 223770                       371                983.0  109.1   3355481.0
# 291630                       334                974.0  104.6   3336504.0
# 291631                       334                974.0  104.6   3336504.0
# 291632                       334                974.0  104.6   3336504.0
# 440730                       251                954.0   99.8   3320299.0
# 494994                       193                903.0  124.9   3292431.0
# 549234                       152               1004.0  143.3   3276637.0
# 603474                       142                956.0  112.4   3254884.0
# 657714                       131                897.0  113.7   3230411.0
# 711954                       140                895.0  109.8   3231140.0
# 766194                       125                883.0  104.1   3206477.0
#
# [12 rows x 38 columns]

# %% [markdown]
# #### Multiple tumor detection model

# %%
mtumors_model = select_best_model_for(st_df, "mtumors", ommit=["age_group", "year", "gdp", "region", "category", "syncmtumors", "insitu", "ncervix", "incidence"])

# %%
print(mtumors_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                mtumors   R-squared:                       0.834
# Model:                            OLS   Adj. R-squared:                  0.820
# Method:                 Least Squares   F-statistic:                     57.83
# Date:                Mon, 24 Mar 2025   Prob (F-statistic):           3.03e-89
# Time:                        19:21:00   Log-Likelihood:                 1238.2
# No. Observations:                 288   AIC:                            -2428.
# Df Residuals:                     264   BIC:                            -2341.
# Df Model:                          23
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.0353      0.003     10.283      0.000       0.029       0.042
# nbeds                   0.0754      0.021      3.580      0.000       0.034       0.117
# ybeds                  -0.0996      0.022     -4.567      0.000      -0.143      -0.057
# nill                    0.0026      0.000      8.574      0.000       0.002       0.003
# nvillage_ill           -0.0036      0.000    -20.302      0.000      -0.004      -0.003
# dvisits              1.943e-05   5.12e-06      3.793      0.000    9.35e-06    2.95e-05
# hvisits             -6.054e-05   3.35e-05     -1.806      0.072      -0.000    5.46e-06
# ndoctors               -0.0677      0.021     -3.233      0.001      -0.109      -0.026
# nflurography            4.4071      0.816      5.398      0.000       2.800       6.015
# nradiology             39.6726      5.447      7.284      0.000      28.948      50.397
# nradlab                18.6395      5.990      3.112      0.002       6.845      30.434
# nсt                    -9.1468      2.644     -3.459      0.001     -14.353      -3.941
# ncardiogram            -0.4830      0.164     -2.938      0.004      -0.807      -0.159
# ndiaglab                0.9598      0.270      3.560      0.000       0.429       1.491
# nbacter                -5.7219      1.202     -4.759      0.000      -8.089      -3.354
# nbiochem              -27.2635      3.865     -7.053      0.000     -34.874     -19.653
# ncyto                 -15.2794      3.116     -4.904      0.000     -21.414      -9.145
# nimun                 -19.1672      3.974     -4.823      0.000     -26.992     -11.343
# nphysic                -0.9264      0.303     -3.053      0.002      -1.524      -0.329
# nultrasound             1.1805      0.731      1.614      0.108      -0.260       2.621
# ndialysis               5.1822      2.803      1.849      0.066      -0.337      10.701
# num_clearing_plants -9.712e-06   2.21e-06     -4.402      0.000   -1.41e-05   -5.37e-06
# cpi                 -7.046e-05   2.12e-05     -3.316      0.001      -0.000   -2.86e-05
# population          -5.786e-09    8.6e-10     -6.728      0.000   -7.48e-09   -4.09e-09
# ==============================================================================
# Omnibus:                       20.711   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               41.031
# Skew:                           0.380   Prob(JB):                     1.23e-09
# Kurtosis:                       4.685   Cond. No.                     6.17e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.17e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# #### Insitu tumor detection model

# %%
insitu_model = select_best_model_for(st_df, "insitu", ommit=["age_group", "year", "gdp", "region", "category", "syncmtumors", "ncervix", "mtumors", "incidence"])

# %%
print(insitu_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 insitu   R-squared:                       0.390
# Model:                            OLS   Adj. R-squared:                  0.358
# Method:                 Least Squares   F-statistic:                     12.44
# Date:                Mon, 24 Mar 2025   Prob (F-statistic):           2.15e-22
# Time:                        19:21:00   Log-Likelihood:                 1390.4
# No. Observations:                 288   AIC:                            -2751.
# Df Residuals:                     273   BIC:                            -2696.
# Df Model:                          14
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0055      0.001     -3.801      0.000      -0.008      -0.003
# ybeds            -0.0156      0.003     -4.753      0.000      -0.022      -0.009
# nill              0.0008      0.000      6.203      0.000       0.001       0.001
# nvillage_ill      0.0002   8.03e-05      2.443      0.015    3.81e-05       0.000
# hvisits        2.825e-05   1.35e-05      2.096      0.037    1.71e-06    5.48e-05
# nnursing         -0.0072      0.004     -1.860      0.064      -0.015       0.000
# nradlab           4.7081      3.056      1.541      0.125      -1.308      10.724
# nсt               3.1656      1.281      2.471      0.014       0.644       5.687
# nbacter          -1.2122      0.556     -2.182      0.030      -2.306      -0.118
# ncyto             6.8796      1.465      4.697      0.000       3.996       9.763
# nimun            -6.6606      1.839     -3.622      0.000     -10.281      -3.041
# nphysic          -0.0815      0.052     -1.582      0.115      -0.183       0.020
# nendoscop         0.7511      0.437      1.720      0.087      -0.109       1.611
# air_pollution -5.528e-06   8.78e-07     -6.294      0.000   -7.26e-06    -3.8e-06
# population     2.524e-09   4.01e-10      6.288      0.000    1.73e-09    3.31e-09
# ==============================================================================
# Omnibus:                      151.613   Durbin-Watson:                   1.882
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1455.023
# Skew:                           1.921   Prob(JB):                         0.00
# Kurtosis:                      13.320   Cond. No.                     4.91e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.91e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
